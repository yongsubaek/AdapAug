# %%
# %matplotlib inline    
import torch
import numpy as np
import matplotlib.pyplot as plt

# %%
data = torch.load("./models/c100_w28-10_n3/controller.pt")

# %%
mean_probs = data["mean_probs"]

# %%
plt.plot(mean_probs)
