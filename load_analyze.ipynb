# %%
import numpy as np
import torch
from collections import Counter

# %%
data = np.load("tmp2.npz", allow_pickle=True)
inputs = data["inputs"]
pols = data["pols"]
bins = data["bins"]

# %%
for bin in bins:
    print(dict(Counter(bin).most_common(2)))
# Out:
# {(('Color', '0.6', '1.0'), ('TranslateX', '0.0', '0.4')): 2, (('Color', '0.3', '0.4'), ('Contrast', '0.1', '0.5')): 2}
# {(('AutoContrast', '0.7', '0.7'), ('Brightness', '0.5', '0.2')): 2, (('Cutout', '0.3', '0.1'), ('Brightness', '0.4', '0.5')): 2}
# {(('AutoContrast', '0.1', '0.7'), ('Sharpness', '0.1', '0.6')): 2, (('Brightness', '0.2', '0.5'), ('Rotate', '0.2', '0.9')): 1}
# {(('Posterize', '0.0', '0.7'), ('Posterize', '1.0', '0.6')): 2, (('Contrast', '0.5', '0.2'), ('ShearX', '0.2', '0.6')): 1}
# {(('ShearX', '0.0', '1.0'), ('ShearX', '0.2', '0.6')): 2, (('TranslateY', '0.0', '0.5'), ('Sharpness', '0.1', '0.4')): 2}
# {(('Color', '0.2', '0.5'), ('Posterize', '0.1', '0.4')): 2, (('AutoContrast', '0.2', '1.0'), ('AutoContrast', '0.5', '0.7999999999999999')): 1}
# {(('Invert', '0.9', '0.4'), ('ShearY', '1.0', '0.2')): 2, (('Cutout', '0.2', '0.6'), ('Sharpness', '0.1', '0.9')): 2}
# ...

# %%
len(bins)
# Out:
# 20

# %%
for i in range(100):
    print(pols[1][5*i:5*i+5])
    print("-"*100)
# Out:
# [[['Contrast' '0.5' '1.0']
#   ['AutoContrast' '0.1' '0.9']]
#
#  [['Contrast' '0.6' '0.5']
#   ['Rotate' '0.0' '0.4']]
#
#  [['ShearY' '0.3' '0.1']
#   ['Color' '0.3' '0.4']]
#
#  [['Cutout' '0.0' '0.4']
#   ['Sharpness' '0.3' '0.1']]
#
#  [['Sharpness' '0.0' '0.7']
#   ['ShearX' '0.6' '0.7999999999999999']]]
# ----------------------------------------------------------------------------------------------------
# [[['ShearY' '0.7' '0.7']
#   ['TranslateY' '0.3' '0.2']]
#
#  [['Posterize' '0.0' '0.7']
#   ['Cutout' '0.4' '0.5']]
#
#  [['Cutout' '0.3' '0.7999999999999999']
#   ['Cutout' '0.4' '0.30000000000000004']]
#
#  [['Sharpness' '0.4' '0.1']
#   ['Color' '0.0' '0.6']]
#
#  [['AutoContrast' '0.0' '0.5']
#   ['Color' '0.4' '0.6']]]
# ----------------------------------------------------------------------------------------------------
# [[['Posterize' '0.0' '0.7999999999999999']
#   ['Sharpness' '0.1' '0.30000000000000004']]
#
#  [['Sharpness' '0.4' '0.6']
# ...

# %%
pols[1][5:10]
# Out:
# array([[['ShearY', '0.7', '0.7'],
#         ['TranslateY', '0.3', '0.2']],
#
#        [['Posterize', '0.0', '0.7'],
#         ['Cutout', '0.4', '0.5']],
#
#        [['Cutout', '0.3', '0.7999999999999999'],
#         ['Cutout', '0.4', '0.30000000000000004']],
#
#        [['Sharpness', '0.4', '0.1'],
#         ['Color', '0.0', '0.6']],
#
#        [['AutoContrast', '0.0', '0.5'],
#         ['Color', '0.4', '0.6']]], dtype='<U19')
